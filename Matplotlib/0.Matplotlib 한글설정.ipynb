# %% [markdown]
# # 한글폰트 설치

# %%
# 일단 import 
 # 매직커맨드
# %matplotlib inline 


import matplotlib as mpl  # 기본 설정 만지는 용도
import matplotlib.pyplot as plt  # 그래프 그리는 용도
import matplotlib.font_manager as fm  # 폰트 관련 용도

# %% [markdown]
# ## 한글 깨지는 것 확인하기

# %%
# 데이터 준비
import numpy as np

data = np.random.randint(-200, 100, 50).cumsum()
data
# 한글을 넣어놓고 그러보면 깨진다
plt.figure(figsize=(6,4))
plt.plot(range(50), data, 'r')
plt.title('시간별 가격추이')
plt.ylabel('주식가격')
plt.xlabel('시간(분)')
# Out:
# Text(0.5, 0, '시간(분)')
# C:\Users\wjh29\AppData\Roaming\Python\Python310\site-packages\IPython\core\events.py:93: UserWarning: Glyph 51452 (\N{HANGUL SYLLABLE JU}) missing from current font.
#   func(*args, **kwargs)
# C:\Users\wjh29\AppData\Roaming\Python\Python310\site-packages\IPython\core\events.py:93: UserWarning: Glyph 49885 (\N{HANGUL SYLLABLE SIG}) missing from current font.
#   func(*args, **kwargs)
# C:\Users\wjh29\AppData\Roaming\Python\Python310\site-packages\IPython\core\events.py:93: UserWarning: Glyph 44032 (\N{HANGUL SYLLABLE GA}) missing from current font.
#   func(*args, **kwargs)
# C:\Users\wjh29\AppData\Roaming\Python\Python310\site-packages\IPython\core\events.py:93: UserWarning: Glyph 44201 (\N{HANGUL SYLLABLE GYEOG}) missing from current font.
#   func(*args, **kwargs)
# C:\Users\wjh29\AppData\Roaming\Python\Python310\site-packages\IPython\core\events.py:93: UserWarning: Glyph 49884 (\N{HANGUL SYLLABLE SI}) missing from current font.
#   func(*args, **kwargs)
# C:\Users\wjh29\AppData\Roaming\Python\Python310\site-packages\IPython\core\events.py:93: UserWarning: Glyph 44036 (\N{HANGUL SYLLABLE GAN}) missing from current font.
#   func(*args, **kwargs)
# C:\Users\wjh29\AppData\Roaming\Python\Python310\site-packages\IPython\core\events.py:93: UserWarning: Glyph 48324 (\N{HANGUL SYLLABLE BYEOL}) missing from current font.
#   func(*args, **kwargs)
# C:\Users\wjh29\AppData\Roaming\Python\Python310\site-packages\IPython\core\events.py:93: UserWarning: Glyph 52628 (\N{HANGUL SYLLABLE CU}) missing from current font.
#   func(*args, **kwargs)
# C:\Users\wjh29\AppData\Roaming\Python\Python310\site-packages\IPython\core\events.py:93: UserWarning: Glyph 51060 (\N{HANGUL SYLLABLE I}) missing from current font.
#   func(*args, **kwargs)
# C:\Users\wjh29\AppData\Roaming\Python\Python310\site-packages\IPython\core\events.py:93: UserWarning: Glyph 48516 (\N{HANGUL SYLLABLE BUN}) missing from current font.
#   func(*args, **kwargs)
# C:\Users\wjh29\AppData\Roaming\Python\Python310\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 51452 (\N{HANGUL SYLLABLE JU}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\wjh29\AppData\Roaming\Python\Python310\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 49885 (\N{HANGUL SYLLABLE SIG}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\wjh29\AppData\Roaming\Python\Python310\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 44032 (\N{HANGUL SYLLABLE GA}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\wjh29\AppData\Roaming\Python\Python310\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 44201 (\N{HANGUL SYLLABLE GYEOG}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\wjh29\AppData\Roaming\Python\Python310\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 49884 (\N{HANGUL SYLLABLE SI}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\wjh29\AppData\Roaming\Python\Python310\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 44036 (\N{HANGUL SYLLABLE GAN}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\wjh29\AppData\Roaming\Python\Python310\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 48324 (\N{HANGUL SYLLABLE BYEOL}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\wjh29\AppData\Roaming\Python\Python310\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 52628 (\N{HANGUL SYLLABLE CU}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\wjh29\AppData\Roaming\Python\Python310\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 51060 (\N{HANGUL SYLLABLE I}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\wjh29\AppData\Roaming\Python\Python310\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 48516 (\N{HANGUL SYLLABLE BUN}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)

# %% [markdown]
# ## 시스템에 설치된 폰트 확인.

# %%
sys_font=fm.findSystemFonts()
print(f"sys_font number: {len(sys_font)}")
print(sys_font)

font = [f for f in sys_font if 'Nanum' in f]  #나눔폰트찾기
print(f"nanum_font number: {len(font)}")

font
# Out:
# sys_font number: 394
# ['C:\\Windows\\Fonts\\GOTHICI.TTF', 'C:\\Windows\\Fonts\\LSANSDI.TTF', 'C:\\Windows\\Fonts\\HANBatang.ttf', 'C:\\Windows\\Fonts\\BOD_PSTC.TTF', 'C:\\Windows\\Fonts\\JUICE___.TTF', 'C:\\Windows\\Fonts\\BELL.TTF', 'C:\\Windows\\Fonts\\TCMI____.TTF', 'C:\\Windows\\Fonts\\PERTILI.TTF', 'C:\\Windows\\Fonts\\MB.TTF', 'C:\\Windows\\Fonts\\HMKMRHD.TTF', 'C:\\Windows\\Fonts\\HTOWERTI.TTF', 'C:\\Windows\\Fonts\\SNAP____.TTF', 'C:\\Windows\\Fonts\\GOUDYSTO.TTF', 'C:\\Windows\\Fonts\\BRLNSDB.TTF', 'C:\\Windows\\Fonts\\LFAXD.TTF', 'C:\\Windows\\Fonts\\BOOKOSBI.TTF', 'C:\\Windows\\Fonts\\verdanaz.ttf', 'C:\\Windows\\Fonts\\HMFMPYUN.TTF', 'C:\\Windows\\Fonts\\LCALLIG.TTF', 'C:\\Windows\\Fonts\\wingding.ttf', 'C:\\Windows\\Fonts\\COLONNA.TTF', 'C:\\Windows\\Fonts\\mvboli.ttf', 'C:\\Windows\\Fonts\\MH.TTF', 'C:\\Windows\\Fonts\\NirmalaB.ttf', 'C:\\Windows\\Fonts\\verdana.ttf', 'C:\\Windows\\Fonts\\FRAHVIT.TTF', 'C:\\Windows\\Fonts\\ariblk.ttf', 'C:\\Windows\\Fonts\\segmdl2.ttf', 'C:\\Windows\\Fonts\\msy
fonts\\BOD_BI.TTF', 'C:\\Windows\\Fonts\\seguiemj.ttf', 'C:\\Windows\\Fonts\\LFAX.TTF', 'C:\\Windows\\Fonts\\tahoma.ttf', 'C:\\Windows\\Fonts\\calibrili.ttf', 'C:\\Windows\\Fonts\\FRADM.TTF', 'C:\\Windows\\Fonts\\TCCEB.TTF', 'C:\\Windows\\Fonts\\GIL_____.TTF', 'C:\\Windows\\Fonts\\LSANS.TTF', 'C:\\Windows\\Fonts\\GLECB.TTF', 'C:\\Windows\\Fonts\\BRITANIC.TTF', 'C:\\Windows\\Fonts\\msjhbd.ttc', 'C:\\Windows\\Fonts\\LFAXDI.TTF', 'C:\\Windows\\Fonts\\ITCBLKAD.TTF', 'C:\\Windows\\Fonts\\holomdl2.ttf', 'C:\\Windows\\Fonts\\BOOKOSB.TTF', 'C:\\Windows\\Fonts\\msjhl.ttc', 'C:\\Windows\\Fonts\\LBRITE.TTF', 'C:\\Windows\\Fonts\\courbd.ttf', 'C:\\Windows\\Fonts\\symbol.ttf', 'C:\\Windows\\Fonts\\seguibli.ttf', 'C ...
# nanum_font number: 8
# ['C:\\Windows\\Fonts\\NanumMyeongjoExtraBold.ttf',
#  'C:\\Windows\\Fonts\\NanumGothicBold.ttf',
#  'C:\\Users\\wjh29\\AppData\\Local\\Microsoft\\Windows\\Fonts\\NanumGothic_0.ttf',
#  'C:\\Windows\\Fonts\\NanumGothicExtraBold.ttf',
#  'C:\\Windows\\Fonts\\NanumMyeongjoBold.ttf',
#  'C:\\Windows\\Fonts\\NanumGothicLight.ttf',
#  'C:\\Windows\\Fonts\\NanumGothic.ttf',
#  'C:\\Windows\\Fonts\\NanumMyeongjo.ttf']

# %%
font = [f for f in sys_font if 'malgun' in f]  #맑은폰트찾기
print(f"Malgun_font number: {len(font)}")
font
# Out:
# Malgun_font number: 3
# ['C:\\Windows\\Fonts\\malgun.ttf',
#  'C:\\Windows\\Fonts\\malgunsl.ttf',
#  'C:\\Windows\\Fonts\\malgunbd.ttf']

# %% [markdown]
# ## matplotlib 글꼴 패밀리 검색

# %%
import matplotlib.pyplot as plt
import matplotlib.font_manager as fm

#메모리 상에 현재 설정되어 있는 폰트 패밀리 이름
font_family = plt.rcParams['font.family']
font_family
# Out:
# ['sans-serif']

# %%
#맷플랏립의 기본 글꼴-> 한글표현 안 되겠쥬
fm.FontManager().defaultFont
# Out:
# {'ttf': 'C:\\Python\\Python310\\Lib\\site-packages\\matplotlib\\mpl-data\\fonts\\ttf\\DejaVuSans.ttf',
#  'afm': 'C:\\Python\\Python310\\Lib\\site-packages\\matplotlib\\mpl-data\\fonts\\afm\\phvr8a.afm'}

# %%
# matplotlib 한글 폰트 오류 문제 해결 

import matplotlib.font_manager as fm
import matplotlib.pyplot as plt

#폰트파일위치 지정해서 설정
font_path = './NanumGothic.ttf'
font_name = fm.FontProperties(fname=font_path).get_name()

#폰트 설정
plt.rc('font', family=font_name)

# 마이너스 깨짐 현상 해결
plt.rcParams['axes.unicode_minus'] = False

# matplotlib 폰트 패밀리 출력
plt.rcParams['font.family']
# Out:
# ['NanumGothic']

# %%
# 데이터 준비
import numpy as np
import matplotlib.pyplot as plt
import matplotlib as mpl  # 기본 설정 만지는 용도

data = np.random.randint(-200, 100, 50).cumsum()
data

## 폰트 설정 및 마이너스 부호 설정
plt.rc('font', family='NanumGothic') #나눔 글꼴로 설정
#plt.rc('font', family='Malgun Gothic') #맑은 고딕으로 설정
#plt.rc('font', family='AppleGothic') #맥
plt.rcParams['axes.unicode_minus'] = False #부호


# 한글을 넣어놓고 그러보면 깨진다
plt.figure(figsize=(6,4))
plt.plot(range(50), data, 'r')
plt.title('시간별 가격추이')
plt.ylabel('주식가격')
plt.xlabel('시간(분)')
# Out:
# Text(0.5, 0, '시간(분)')
